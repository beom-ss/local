# %% [markdown]
# 주가 예측 모형 구축

# %% [markdown]
# # 1. Setting Enviroment

# %% [markdown]
# ## 1.1. Import library

# %%
# library import
import os
import sys
import time
import numpy as np
import scipy as sp
import pandas as pd
import re
from datetime import datetime, timedelta
from IPython.display import clear_output
import matplotlib.pyplot as plt

# crawling
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import json
import urllib3
import http.client

# Oracle DB 연동
import cx_Oracle

# autocomplete 작동 안될때
# %config Completer.use_jedi = False

# %%
from sklearn.model_selection import cross_val_score, RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import lightgbm as lgb

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ## 1.2. Connect Oracle

# %%
# 한글 지원
os.putenv('NLS_LANG', '.UTF8')

username = 'system'
password = 'kv5900'
host = 'localhost/orcl'

# DB connect
conn = cx_Oracle.connect(username, password, host)

# %%
# test sql code
pd.read_sql('select * from DUAL', conn)
# Out:
#   DUMMY
# 0     X

# %% [markdown]
# ## 1.3. Setting working directory

# %%
os.chdir('E:\\github\\python\\stock')

# %%
os.getcwd()
# Out:
# 'E:\\github\\python\\stock'

# %% [markdown]
# ## 1.4. Setting Variables

# %% [markdown]
# #### 가장 최근 영업일 crawling

# %%
url = 'https://finance.naver.com/sise/sise_index.nhn?code=KOSPI'

html = urlopen(url)
source = BeautifulSoup(html.read(), "lxml")
text = source.find_all('span', id='time')[0].text

basc_dt = re.sub('\\.', '', re.findall(('[0-9]+.[0-9]+.[0-9]+'), text)[0])
print(basc_dt)
# Out:
# 20210713

# %%
basc_dt='20210712'

# %%
stt_dt = '20000101'

# %% [markdown]
# # 2. Import Data

# %% [markdown]
# #### ticker 정보 호출

# %%
kr_tkr = pd.read_sql('select * from STC_DMS_TKR', conn)

# %%
data_sector = pd.read_sql('select * from STC_DMS_TKR_SCT', conn)

# %% [markdown]
# #### 재무분석 결과 rank 테이블 호출

# %%
q = "select * from STC_DMS_TKR_RNK where BASC_DT = '" + basc_dt + "'"
rank_db = pd.read_sql(q, conn)

# %%
rank_db.head()
# Out:
#     BASC_DT  TKR_CD TKR_NM SCT_LRG_CD SCT_LRG_NM SCT_SML_CD SCT_SML_NM MKT_GB  \
# 0  20210712  000020   동화약품        G35       건강관리      G3520    제약과생물공학  KOSPI
# 1  20210712  000040  KR모터스        G25    경기관련소비재      G2510     자동차와부품  KOSPI
# 2  20210712  000050     경방        G25    경기관련소비재      G2520   내구소비재와의류  KOSPI
# 3  20210712  000060  메리츠화재        G40         금융      G4040         보험  KOSPI
# 4  20210712  000070  삼양홀딩스        G30      필수소비재      G3020   식품,음료,담배  KOSPI
#
#   IND_CAT       MKT_CAP     DPS    RANK     Z_STD    Z_MMTM   Z_YYPRF  \
# 0     의약품  4.203686e+11   180.0   419.0  0.474515  0.598316 -0.925698
# 1    운수장비  1.216138e+11     0.0  2054.0  0.535961  0.042814  0.268394
# 2     유통업  3.865553e+11   125.0  1431.0 -0.879854  0.538075  0.330346
# 3      보험  2.490906e+12  1280.0   994.0 -0.187683 -0.834823  0.100000
# 4    기타금융  8.735556e+11  2250.0   415.0  0.515872 -0.105445 -0.152906
#
#     Z_YYSTB   Z_YYGRW   Z_YYACT   Z_QQPRF   Z_QQSTB   Z_QQGRW   Z_QQACT  \
# 0 -0.983137 -0.517930  0.310946 -0.684393 -0.768127  0.056936  0.212550
# 1  0.647460  0.413116  0.367596  0.876035  0.917492 -0.262817  0.898729
# 2  0.660397  0.491659  0.061503  0.200844  0.665356  0.020349  0.081425
# 3  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 4  0.070713 -0.455587 -0.092821 -0.350002  0.214679 -0.692918 -0.223353
#
#       Z_VAL      Z_MG
# 0 -0.147765 -1.169446
# 1 -0.161054  0.937814
# 2 -0.185893 -0.111951
# 3  0.100000  0.100000
# 4 -1.012787 -0.869505

# %% [markdown]
# #### 국내주식 정보 호출 (재무분석 결과에 따라 상위 ticker만 호출)

# %%
kr_tkr_slt = rank_db.sort_values('RANK').iloc[:30,1].tolist()

# %%
kr_tkr_slt = "'"+"','".join(kr_tkr_slt)+"'"

# %%
q = """

select *
  from STC_DMS_TKR_PRC
 where 1=1
   and BASC_DT between '"""+ stt_dt +"""' and '"""+ basc_dt +"""'
   and TKR_CD in ("""+kr_tkr_slt+""")

"""

price_slt = pd.read_sql(q, conn)
price_slt = price_slt.sort_values(['TKR_CD','BASC_DT']).reset_index(drop=True) # 순서 정렬
price_slt = price_slt.replace(0, np.nan).groupby(['TKR_CD', 'BASC_DT']).mean().ffill().reset_index() # 값이 0인 경우 null로 치환 후 ffill (거래정지가 있는 경우)

# %%
price_slt.head()
# Out:
#    TKR_CD   BASC_DT  OPN_PRC  HGH_PRC  LOW_PRC  CLS_PRC      VLM
# 0  007540  20000104   4011.0   4229.0   3782.0     3994   5610.0
# 1  007540  20000105   4108.0   4108.0   3703.0     3752   6680.0
# 2  007540  20000106   3866.0   3866.0   3637.0     3685   5040.0
# 3  007540  20000107   3806.0   3927.0   3637.0     3927  14550.0
# 4  007540  20000110   3927.0   4168.0   3691.0     3957  14560.0

# %% [markdown]
# #### 주요 지표 호출

# %%
# 비트코인은 아직 값이 너무 부족해서 그냥 제외시킴
idx_list = {'STC_IDX_SP'      : 'SP',          # S&P
            'STC_IDX_DOW'     : 'DOW',         # 다우 
            'STC_IDX_NQ'      : 'NQ',          # 나스닥 
            'STC_IDX_RS2000'  : 'RS2000',      #러셀2000
            'STC_IDX_NI225'   : 'NI225',       # 일본
            'STC_IDX_SSE'     : 'SSE',         # 중국
            'STC_IDX_HSI'     : 'HSI',         # 홍콩
            'STC_IDX_FTSE'    : 'FTSE',        # 영국 
            'STC_IDX_FCHI'    : 'FCHI',        # 프랑스 
            'STC_IDX_GDAXI'   : 'GDAXI',       # 독일
            'STC_IDX_CLOIL'   : 'CLOIL',       # 크루드오일
            'STC_IDX_GOLD'    : 'GOLD',        # 금
            'STC_IDX_SILVER'  : 'SILVER',      # 은
            'STC_IDX_USD_KRW' : 'USD_KRW',     # 달러-원화
            'STC_IDX_USD_JPY' : 'USD_JPY',     # 달러-엔화
            'STC_IDX_USD_EUR' : 'USD_EUR',     # 달러-유로
            'STC_IDX_USD_GBP' : 'USD_GBP',     # 달러-영국파운드
#             'STC_IDX_BTC_USD' : 'BTC_USD',     # 비트코인 달러
#             'STC_IDX_BTC_KRW' : 'BTC_KRW',     # 비트코인 한화
            'STC_IDX_KOSPI'   : 'KOSPI',       # 코스피
            'STC_IDX_KOSDAQ'  : 'KOSDAQ',      # 코스닥
#             'STC_IDX_KPI200'  : 'KPI200'       # 코스피200
           }

# %%
# 모든 데이터 호출
for db_df, out_df in idx_list.items():
    q = "select * from "+ db_df + " where BASC_DT between " + stt_dt + " and " + basc_dt
    exec("{} = pd.read_sql(q, conn)".format(out_df))
    
    # 컬럼명 변경 (종가,저가,고가,시가 앞에 지표명 추가)
    exec("{}.rename(columns = dict(zip({}.columns[2:], '{}'+'_'+{}.columns[2:])), inplace=True)".format(out_df, out_df, out_df, out_df))

# %%
# 지표테이블 조인
for i, val in enumerate(idx_list.items()):
    
    db_df = val[0] # input table name (in sql)
    out_df = val[1] # call table name (in python)
    
    # loop를 위해.. df로 테이블명 통일
    exec("df = {}".format(out_df))
    
    df = df.drop('IDX_CD', inplace=False, axis=1) # IDX_CD 컬럼 제거
    if (i == 0):
        idx_df = df
    else:
        idx_df = idx_df.merge(df, how='outer', on='BASC_DT')
        
# order by BASC_DT        
idx_df = idx_df.sort_values('BASC_DT').reset_index(drop=True)

# 모든 컬럼값이 0 or na인 경우 제외
idx_df = idx_df.loc[:,idx_df.columns[~(idx_df.apply(lambda x: pd.Series([x.min(), x.max()])).sum() == 0)]]

# 0인값을 모두 null 처리함
idx_df = idx_df.replace(0, np.nan)

# index를 통한 join
#     exec("{} = {}.drop('IDX_CD', inplace=False, axis=1).set_index('BASC_DT')".format(out_df, out_df))
#     exec("idx = pd.concat([idx, {}], ignore_index=False, axis=1)".format(out_df))

# %% [markdown]
# ### 결측 및 이상치 처리

# %%
# outlier 이상치 탐색
# idx_df.describe(percentiles = [.01,.05,.10,.25,.50,.75,.90,.95,.99]).T.to_csv('percentiles.csv')
idx_df.describe(percentiles = [.01,.05,.10,.25,.50,.75,.90,.95,.99]).T
# Out:
#                   count          mean           std           min  \
# SP_OPN_PRC       5415.0  1.711258e+03  7.609878e+02  6.792800e+02
# SP_HGH_PRC       5415.0  1.721143e+03  7.635850e+02  6.952700e+02
# SP_LOW_PRC       5415.0  1.700570e+03  7.582624e+02  6.667900e+02
# SP_CLS_PRC       5415.0  1.711508e+03  7.612899e+02  6.765300e+02
# SP_VLM           5415.0  3.211058e+09  1.524634e+09  3.560700e+08
# SP_ADJ_PRC       5415.0  1.711508e+03  7.612899e+02  6.765300e+02
# DOW_OPN_PRC      5415.0  1.509573e+04  6.378323e+03  6.547010e+03
# DOW_HGH_PRC      5415.0  1.518498e+04  6.402080e+03  6.709610e+03
# DOW_LOW_PRC      5415.0  1.500304e+04  6.354311e+03  6.469950e+03
# DOW_CLS_PRC      5415.0  1.509867e+04  6.380131e+03  6.547050e+03
# DOW_VLM          5415.0  2.314316e+08  1.113325e+08  8.410000e+06
# DOW_ADJ_PRC      5415.0  1.509867e+04  6.380131e+03  6.547050e+03
# NQ_OPN_PRC       5415.0  4.030540e+03  2.787767e+03  1.116760e+03
# KOSDAQ_HGH_PRC   6.048200e+02  7.101100e+02  8.490800e+02  9.673040e+02
# KOSDAQ_LOW_PRC   5.962300e+02  7.000000e+02  8.293680e+02  9.535760e+02
# KOSDAQ_CLS_PRC   6.004900e+02  7.044325e+02  8.381000e+02  9.614330e+02
# KOSDAQ_VLM       5.417795e+05  7.154350e+05  9.837122e+05  1.521353e+06
#
#                           99%           max
# SP_OPN_PRC       4.139623e+03  4.372410e+03
# SP_HGH_PRC       4.171532e+03  4.386680e+03
# SP_LOW_PRC       4.124327e+03  4.364030e+03
# SP_CLS_PRC       4.150629e+03  4.384630e+03
# SP_VLM           7.614222e+09  1.145623e+10
# SP_ADJ_PRC       4.150629e+03  4.384630e+03
# DOW_OPN_PRC      3.384901e+04  3.483675e+04
# DOW_HGH_PRC      3.403071e+04  3.509156e+04
# DOW_LOW_PRC      3.368448e+04  3.474157e+04
# DOW_CLS_PRC      3.386713e+04  3.499618e+04
# DOW_VLM          5.849860e+08  9.159900e+08
# DOW_ADJ_PRC      3.386713e+04  3.499618e+04
# NQ_OPN_PRC       1.377049e+04  1.475341e+04
# NQ_HGH_PRC       1.382837e+04  1.476108e+04
# NQ_LOW_PRC       1.369774e+04  1.467263e+04
# NQ_CLS_PRC       1.377474e+04  1.473324e+04
# NQ_VLM           5.953065e+09  1.110216e+10
# NQ_ADJ_PRC       1.377474e+04  1.473324e+04
# RS2000_OPN_PRC   2.263716e+03  2.360130e+03
# RS2000_HGH_PRC   2.279338e+03  2.360170e+03
# RS2000_LOW_PRC   2.234763e+03  2.337130e+03
# RS2000_CLS_PRC   2.264579e+03  2.360170e+03
# RS2000_VLM       7.633662e+09  1.145623e+10
# RS2000_ADJ_PRC   2.264579e+03  2.360170e+03
# NI225_OPN_PRC    2.912326e+04  3.036682e+04
# NI225_HGH_PRC    2.923543e+04  3.071452e+04
# NI225_LOW_PRC    2.895451e+04  3.019165e+04
# NI225_CLS_PRC    2.904963e+04  3.046775e+04
# NI225_VLM        2.970780e+08  5.952000e+08
# NI225_ADJ_PRC    2.904963e+04  3.046775e+04
# SSE_OPN_PRC      5.289116e+03  6.057428e+03
# SSE_HGH_PRC      5.338153e+03  6.124044e+03
# SSE_LOW_PRC      5.217102e+03  6.040713e+03
# SSE_CLS_PRC      5.307702e+03  6.092057e+03
# SSE_VLM          5.977560e+05  1.709250e+09
# SSE_ADJ_PRC      5.307702e+03  6.092057e+03
# HSI_OPN_PRC      3.102869e+04  3.333548e+04
# HSI_HGH_PRC      3.114826e+04  3.348408e+04
# HSI_LOW_PRC      3.074391e+04  3.289704e+04
# HSI_CLS_PRC      3.096599e+04  3.315412e+04
# HSI_VLM          4.364888e+09  9.799120e+09
# HSI_ADJ_PRC      3.096599e+04  3.315412e+04
# FTSE_OPN_PRC     7.671408e+03  7.877500e+03
# FTSE_HGH_PRC     7.705662e+03  7.903500e+03
# FTSE_LOW_PRC     7.636163e+03  7.854600e+03
# FTSE_CLS_PRC     7.671408e+03  7.877500e+03
# FTSE_VLM         2.147253e+09  4.420947e+09
# USD_GBP_ADJ_PRC  2.042817e+00  2.108192e+00
# KOSPI_OPN_PRC    3.163749e+03  3.305460e+03
# KOSPI_HGH_PRC    3.183783e+03  3.316080e+03
# KOSPI_LOW_PRC    3.140584e+03  3.295440e+03
# KOSPI_CLS_PRC    3.163114e+03  3.305210e+03
# KOSPI_VLM        1.611061e+06  3.455504e+06
# KOSDAQ_OPN_PRC   2.065624e+03  2.894600e+03
# KOSDAQ_HGH_PRC   2.114268e+03  2.925500e+03
# KOSDAQ_LOW_PRC   1.976564e+03  2.815900e+03
# KOSDAQ_CLS_PRC   2.058145e+03  2.834400e+03
# KOSDAQ_VLM       2.287926e+06  5.067754e+06

# %%
# plot으로 탐색
idx_df.set_index('BASC_DT')['SSE_VLM'].plot()
plt.show()

# %%
# plot으로 탐색
idx_df.set_index('BASC_DT')['USD_KRW_HGH_PRC'].plot()
plt.show()

# %%
# 이상치 처리 일반화 (Q3 + 15*IQR 보다 큰 값만 처리함 - 지나치게 이상한 경우)
cols = idx_df.columns.isin(['BASC_DT'])
idx_df.loc[:,~cols] = idx_df.loc[:,~cols].apply(lambda x: x[(x< (x.quantile(q=.75) + 15*(x.quantile(q=.75)-x.quantile(q=.25))))])

# 이상치 제거
# idx_df.loc[idx_df['BASC_DT']=='20030912','SSE_VLM'] = np.nan  # 말도안되게 큰 값이 들어가있음.. (10065200.0)
# idx_df.loc[idx_df['BASC_DT']=='20080317','USD_KRW_HGH_PRC'] = np.nan  # 말도안되게 큰 값이 들어가있음.. (21353.0)

# %%
# 값이 이상한 변수 제거 (금,은의 거래량 변수의 편차가 너무 심하게 큼)
idx_df = idx_df.drop(['GOLD_VLM','SILVER_VLM'], axis=1)
# 중복변수 제거
idx_df = idx_df.drop(['SP_CLS_PRC','DOW_CLS_PRC','NQ_CLS_PRC','RS2000_CLS_PRC','NI225_CLS_PRC','SSE_CLS_PRC','HSI_CLS_PRC',
                      'FTSE_CLS_PRC','FCHI_CLS_PRC','GDAXI_CLS_PRC','CLOIL_CLS_PRC','GOLD_CLS_PRC','SILVER_CLS_PRC',
                      'USD_KRW_CLS_PRC','USD_JPY_CLS_PRC','USD_EUR_CLS_PRC','USD_GBP_CLS_PRC'], axis=1)

# %%
# 결측치 처리 (linear로 처리함.. 최대 5개)
idx_df = idx_df.interpolate(method='values', limit_area='inside')

# %%
idx_df.shape
# Out:
# (5616, 90)

# %%
# 결측비율이 높은 컬럼 제거 - 5% 미만인 경우만 사용
sltcols = (idx_df.isna().sum(axis=0)/idx_df.shape[0])<0.05
sltcols = sltcols[sltcols].index
idx_df = idx_df[sltcols]

# %%
idx_df.shape
# Out:
# (5616, 74)

# %%
# 결측비율이 낮은 컬럼 처리 - 삭제 (처음과 끝부분만 남아있음 그냥 제거해줌)
narows = idx_df.isna().sum(axis=0)
print(narows[narows>0])
idx_df = idx_df.loc[idx_df.isna().any(axis=1)==False,:]
# Out:
# RS2000_VLM          1
# NI225_OPN_PRC       1
# NI225_HGH_PRC       1
# NI225_LOW_PRC       1
# NI225_ADJ_PRC       1
# SSE_OPN_PRC         1
# SSE_HGH_PRC         1
# SSE_LOW_PRC         1
# SSE_ADJ_PRC         1
# FTSE_OPN_PRC        1
# FTSE_HGH_PRC        1
# FTSE_LOW_PRC        1
# FTSE_VLM            2
# FTSE_ADJ_PRC        1
# GDAXI_VLM           1
# CLOIL_OPN_PRC     167
# CLOIL_HGH_PRC     167
# CLOIL_LOW_PRC     167
# CLOIL_VLM         167
# CLOIL_ADJ_PRC     167
# GOLD_OPN_PRC      172
# GOLD_HGH_PRC      172
# GOLD_LOW_PRC      172
# GOLD_ADJ_PRC      172
# SILVER_OPN_PRC    172
# SILVER_HGH_PRC    172
# SILVER_LOW_PRC    172
# SILVER_ADJ_PRC    172
# KOSPI_OPN_PRC       1
# KOSPI_HGH_PRC       1
# KOSPI_LOW_PRC       1
# KOSPI_CLS_PRC       1
# KOSPI_VLM           1
# KOSDAQ_OPN_PRC      1
# KOSDAQ_HGH_PRC      1
# KOSDAQ_LOW_PRC      1
# KOSDAQ_CLS_PRC      1
# KOSDAQ_VLM          1
# dtype: int64

# %% [markdown]
# ### 테스트 데이터 생성

# %% [markdown]
# #### 종목별 주가 & 지표 Join

# %%
df = price_slt.merge(idx_df, how='inner', on='BASC_DT')

# %%
tt = df.loc[df['TKR_CD']=='007540'].reset_index(drop=True)

# %% [markdown]
# #### Target 변수 생성

# %%
# 기간 내 최대 주가 생성을 위해 기간 지정 (10영업일로 지정)
tt.insert(2, 'TO_DT', tt['BASC_DT'].shift(-10))

# %%
# 최대 주가를 추출하기 위한 function
def create_target(row):
    tmp = tt[tt['BASC_DT'].between(row.BASC_DT, row.TO_DT)]
    return pd.Series([tmp['CLS_PRC'].max()], index=['MAX_PRC'])

# %%
# 최대 주가 추가
tt.insert(3, 'MAX_PRC', tt.apply(create_target, axis=1))

# %%
# 10영업일 이내 최대 수익률 변수 생성 (target)
tt.insert(3, 'TARGET', (tt['MAX_PRC']-tt['CLS_PRC'])/tt['CLS_PRC'])

# %%
tt['TARGET'] = tt['TARGET'].apply(lambda x: 1 if x>=0.1 else 0)

# %%
tt
# Out:
#       TKR_CD   BASC_DT     TO_DT  TARGET  MAX_PRC  OPN_PRC  HGH_PRC  LOW_PRC  \
# 0     007540  20000830  20000918       0   4465.0   4531.0   4591.0   4350.0
# 1     007540  20000831  20000919       0   4465.0   4319.0   4525.0   4319.0
# 2     007540  20000901  20000920       0   4441.0   4507.0   4525.0   4356.0
# 3     007540  20000904  20000921       0   4362.0   4410.0   4470.0   4319.0
# 4     007540  20000905  20000922       0   4169.0   4410.0   4410.0   4168.0
# ...      ...       ...       ...     ...      ...      ...      ...      ...
# 5147  007540  20210705       NaN       0      NaN  58400.0  59100.0  58300.0
# 5148  007540  20210706       NaN       0      NaN  58800.0  59700.0  58700.0
# 5149  007540  20210707       NaN       0      NaN  59300.0  59700.0  58800.0
# 5150  007540  20210708       NaN       0      NaN  58900.0  59000.0  57300.0
# 5151  007540  20210709       NaN       0      NaN  57200.0  57200.0  54600.0
#
#       GOLD_HGH_PRC  GOLD_LOW_PRC  GOLD_ADJ_PRC  SILVER_OPN_PRC  \
# 0       273.899994    273.899994    273.899994        4.950000
# 1       278.299988    274.799988    278.299988        4.920000
# 2       277.000000    277.000000    277.000000        5.035000
# 3       276.399994    276.399994    276.399994        5.012500
# 4       275.799988    275.799988    275.799988        4.990000
# ...            ...           ...           ...             ...
# 5147   1798.850036   1782.500000   1788.049988       26.417501
# 5148   1809.800049   1786.699951   1793.500000       26.725000
# 5149   1808.400024   1797.199951   1801.500000       26.200001
# 5150   1818.500000   1797.000000   1799.599976       26.160000
# 5151   1810.099976   1798.800049   1810.000000       25.965000
#
#       SILVER_HGH_PRC  SILVER_LOW_PRC  SILVER_ADJ_PRC  USD_JPY_OPN_PRC  \
# 0           4.950000        4.895000        4.930000       106.120003
# 1           5.045000        4.920000        5.003000       106.599998
# 2           5.035000        4.985000        5.004000       106.660004
# 3           5.020000        4.980000        5.001000       105.750000
# 4           5.005000        4.975000        4.998000       106.209999
# ...              ...             ...             ...              ...
# 5147       26.772500       26.129500       26.317500       111.139999
# 5148       26.870001       26.153999       26.153999       110.906998
# 5149       26.500000       26.070000       26.110001       110.570000
# 5150       26.290001       25.889999       25.966999       110.622002
# 5151       26.215000       25.834999       26.211000       109.788002
#
#       USD_JPY_HGH_PRC  USD_JPY_LOW_PRC  USD_JPY_ADJ_PRC  KOSPI_OPN_PRC  \
# 0          106.709999       105.830002       106.610001         726.63
# 1          106.820000       106.230003       106.669998         713.41
# 2          106.720001       105.529999       105.949997         690.93
# 3          106.379997       105.550003       106.209999         690.95
# 4          106.500000       105.720001       105.860001         677.74
# ...               ...              ...              ...            ...
# 5147       111.183998       110.797997       111.135002        3285.29
# 5148       110.912003       110.526001       110.916000        3295.44
# 5149       110.806999       110.402000       110.601997        3303.59
# 5150       110.622002       109.535004       110.635002        3287.68
# 5151       110.246002       109.766998       109.801003        3245.52
#
#       KOSPI_HGH_PRC  KOSPI_LOW_PRC  KOSPI_CLS_PRC  KOSPI_VLM  KOSDAQ_OPN_PRC  \
# 0            727.39         718.93         718.93   217557.0         1133.30
# 1            713.41         682.68         688.62   263369.0         1121.00
# 2            698.28         685.32         692.19   202369.0         1086.00
# 3            693.66         677.55         681.30   224053.0         1077.60
# 4            685.05         668.08         679.24   216307.0         1076.90
# ...             ...            ...            ...        ...             ...
# 5147        3298.93        3285.29        3293.21   850406.0         1039.79
# 5148        3313.51        3295.44        3305.21  1029465.0         1047.60
# 5149        3303.59        3277.66        3285.34  1147641.0         1045.00
# 5150        3295.71        3252.41        3252.68  1516034.0         1047.96
# 5151        3245.52        3188.80        3217.95  1308364.0         1031.78
#
#       KOSDAQ_HGH_PRC  KOSDAQ_LOW_PRC  KOSDAQ_CLS_PRC  KOSDAQ_VLM
# 0            1134.00         1113.40         1119.50    212090.0
# 1            1122.80         1057.10         1085.90    199184.0
# 2            1103.00         1073.70         1089.40    229237.0
# 3            1095.30         1072.80         1076.30    170425.0
# 4            1083.20         1058.90         1077.20    175968.0
# ...              ...             ...             ...         ...
# 5147         1048.16         1039.79         1047.33   1743060.0
# 5148         1049.24         1043.51         1044.96   1964143.0
# 5149         1050.31         1042.42         1047.36   1692983.0
# 5150         1049.95         1028.14         1034.48   1869433.0
# 5151         1031.78         1013.91         1028.93   2188638.0
#
# [5152 rows x 83 columns]

# %% [markdown]
# # 3. Create Variables

# %%
train = tt.loc[tt['BASC_DT']< '20200701'].drop(['TKR_CD','BASC_DT','TO_DT','MAX_PRC'], axis=1)
test  = tt.loc[tt['BASC_DT']>='20200701'].drop(['TKR_CD','BASC_DT','TO_DT','MAX_PRC'], axis=1)

# %%
X, y = train.drop(['TARGET'],axis=1).values, train['TARGET']
train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=.2, random_state=1234)

# %%
test_X, test_y = test.drop(['TARGET'],axis=1).values, test['TARGET']

# %% [markdown]
# # 4. Build Models

# %% [markdown]
# #### Lasso 를 활용하여 변수 선택

# %%
lasso = Lasso(alpha=1, random_state=12)
lasso.fit(train_X,train_y)
train_score = lasso.score(train_X,train_y)
valid_score = lasso.score(valid_X,valid_y)
coeff_used = np.sum(lasso.coef_!=0)

print("training score:", train_score)
print("valid score: ", valid_score)
print("number of features used: ", coeff_used)
# Out:
# training score: 0.05638868739354186
# valid score:  0.03889095482376037
# number of features used:  25
# C:\Users\user\anaconda3\envs\gpu\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253.38092204053768, tolerance: 0.05347833078101094
#   positive)

# %%
list(zip(tt.drop(['TARGET','TKR_CD','BASC_DT'],axis=1).columns, lasso.coef_))
# Out:
# [('TO_DT', 1.1016113737377478e-05),
#  ('MAX_PRC', 2.25488376273081e-05),
#  ('OPN_PRC', -6.658972939835455e-05),
#  ('HGH_PRC', 2.4547830350178875e-05),
#  ('LOW_PRC', -3.122268875530378e-08),
#  ('CLS_PRC', 0.0),
#  ('VLM', 0.0),
#  ('SP_OPN_PRC', 0.0),
#  ('SP_HGH_PRC', 3.080016027822235e-11),
#  ('SP_LOW_PRC', 1.9319233743364253e-05),
#  ('SP_VLM', -0.0),
#  ('SP_ADJ_PRC', 0.0),
#  ('DOW_OPN_PRC', 0.0),
#  ('DOW_HGH_PRC', -5.831345539267832e-10),
#  ('DOW_LOW_PRC', 2.710745725873536e-06),
#  ('DOW_VLM', 0.0),
#  ('DOW_ADJ_PRC', 1.2223656430566626e-05),
#  ('NQ_OPN_PRC', 0.0),
#  ('NQ_HGH_PRC', 4.250531090811763e-11),
#  ('NQ_LOW_PRC', 8.5953604277747e-06),
#  ('NQ_VLM', 0.0),
#  ('NQ_ADJ_PRC', 0.0),
#  ('RS2000_OPN_PRC', 0.0),
#  ('RS2000_HGH_PRC', -1.9687512707392624e-11),
#  ('RS2000_LOW_PRC', 0.0),
#  ('RS2000_VLM', 0.0),
#  ('RS2000_ADJ_PRC', 3.0518776455572216e-05),
#  ('NI225_OPN_PRC', 0.0),
#  ('NI225_HGH_PRC', 2.4177765564387144e-06),
#  ('NI225_LOW_PRC', -0.0),
#  ('NI225_ADJ_PRC', -0.0),
#  ('SSE_OPN_PRC', -4.134343430093108e-06),
#  ('SSE_HGH_PRC', -0.0),
#  ('SSE_LOW_PRC', -4.904060379109454e-06),
#  ('SSE_ADJ_PRC', 0.0),
#  ('HSI_OPN_PRC', -0.0),
#  ('HSI_HGH_PRC', 0.0),
#  ('HSI_LOW_PRC', -0.0),
#  ('HSI_ADJ_PRC', -0.0),
#  ('FTSE_OPN_PRC', -0.0),
#  ('FTSE_HGH_PRC', -2.5656004359815384e-11),
#  ('FTSE_LOW_PRC', -0.0),
#  ('FTSE_VLM', -1.862019057799273e-05),
#  ('FTSE_ADJ_PRC', -0.0),
#  ('FCHI_OPN_PRC', -0.0),
#  ('FCHI_HGH_PRC', -0.0),
#  ('FCHI_LOW_PRC', -3.106699881711032e-05),
#  ('FCHI_ADJ_PRC', -0.0),
#  ('GDAXI_OPN_PRC', -0.0),
#  ('GDAXI_HGH_PRC', 5.610766780617683e-10),
#  ('GDAXI_LOW_PRC', 0.0),
#  ('GDAXI_VLM', -0.0),
#  ('GDAXI_ADJ_PRC', -0.0),
#  ('CLOIL_OPN_PRC', -0.0),
#  ('CLOIL_HGH_PRC', -5.932524635494874e-09),
#  ('CLOIL_LOW_PRC', -0.0),
#  ('CLOIL_VLM', 0.0),
#  ('CLOIL_ADJ_PRC', 0.0),
#  ('GOLD_OPN_PRC', 0.0),
#  ('GOLD_HGH_PRC', 0.0),
#  ('GOLD_LOW_PRC', 0.0),
#  ('GOLD_ADJ_PRC', 0.0),
#  ('SILVER_OPN_PRC', 0.0),
#  ('SILVER_HGH_PRC', 0.0),
#  ('SILVER_LOW_PRC', -0.0),
#  ('SILVER_ADJ_PRC', -0.0),
#  ('USD_JPY_OPN_PRC', -0.0),
#  ('USD_JPY_HGH_PRC', -0.0),
#  ('USD_JPY_LOW_PRC', 0.0),
#  ('USD_JPY_ADJ_PRC', 0.0),
#  ('KOSPI_OPN_PRC', 0.0),
#  ('KOSPI_HGH_PRC', 0.0),
#  ('KOSPI_LOW_PRC', 2.7271031861695544e-08),
#  ('KOSPI_CLS_PRC', -2.210981882608013e-05),
#  ('KOSPI_VLM', -0.0),
#  ('KOSDAQ_OPN_PRC', -0.0),
#  ('KOSDAQ_HGH_PRC', -0.0),
#  ('KOSDAQ_LOW_PRC', 1.1408130292850423e-07)]

# %%
lgb_train = lgb.Dataset(train_X, train_y)
lgb_valid = lgb.Dataset(valid_X, valid_y, reference=lgb_train)
lgb_test = lgb.Dataset(test_X, test_y)

# %%
param = {'learning_rate':0.1,
         'max_depth':10,
         'num_leaves':144,
         'min_data_in_leaf':40,
         'boosting':'gbdt',
         'feature_fraction':0.8,
         'bagging_fraction':0.8,
         'bagging_freq':5,
         'objective':'regression',
         'metric':'mse',
         'verbose':5,
         'seed':1234,
         
        }

# %%
lgb_model = lgb.train(params = param, 
                      train_set = lgb_train, 
                      valid_sets = lgb_valid, 
                      num_boost_round=100, 
                      early_stopping_rounds=50)
# Out:
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.000000
# [LightGBM] [Debug] init for col-wise cost 0.000292 seconds, init for row-wise cost 0.001269 seconds
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001854 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19890
# [LightGBM] [Info] Number of data points in the train set: 3918, number of used features: 78
# [LightGBM] [Debug] Use subset for bagging
# [LightGBM] [Info] Start training from score 0.163093
# [LightGBM] [Debug] Re-bagging, using 3157 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and depth = 10
# [1]	valid_0's l2: 0.129788
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and depth = 10
# [2]	valid_0's l2: 0.126292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 48 and depth = 10
# [3]	valid_0's l2: 0.121922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 48 and depth = 10
# [4]	valid_0's l2: 0.118416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and depth = 10
# [5]	valid_0's l2: 0.116044
# [LightGBM] [Debug] Re-bagging, using 3100 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 45 and depth = 10
# [6]	valid_0's l2: 0.112687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [7]	valid_0's l2: 0.109252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [8]	valid_0's l2: 0.106993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and depth = 10
# [9]	valid_0's l2: 0.104527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [10]	valid_0's l2: 0.102224
# [LightGBM] [Debug] Re-bagging, using 3120 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and depth = 10
# [11]	valid_0's l2: 0.101141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and depth = 10
# [12]	valid_0's l2: 0.100148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 44 and depth = 10
# [13]	valid_0's l2: 0.0989242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and depth = 10
# [14]	valid_0's l2: 0.098521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and depth = 10
# [15]	valid_0's l2: 0.0978437
# [LightGBM] [Debug] Re-bagging, using 3130 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and depth = 10
# [16]	valid_0's l2: 0.097505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 39 and depth = 10
# [17]	valid_0's l2: 0.0959408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and depth = 10
# [18]	valid_0's l2: 0.0955403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and depth = 10
# [19]	valid_0's l2: 0.0946914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and depth = 10
# [20]	valid_0's l2: 0.0943075
# [LightGBM] [Debug] Re-bagging, using 3103 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 49 and depth = 10
# [21]	valid_0's l2: 0.0928938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [22]	valid_0's l2: 0.0917994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 47 and depth = 10
# [23]	valid_0's l2: 0.0907484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [24]	valid_0's l2: 0.0899629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and depth = 10
# [25]	valid_0's l2: 0.0896643
# [LightGBM] [Debug] Re-bagging, using 3136 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 18 and depth = 10
# [26]	valid_0's l2: 0.0894516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and depth = 10
# [27]	valid_0's l2: 0.0889989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and depth = 10
# [28]	valid_0's l2: 0.0887656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and depth = 10
# [29]	valid_0's l2: 0.0885978
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 42 and depth = 10
# [30]	valid_0's l2: 0.0881653
# [LightGBM] [Debug] Re-bagging, using 3154 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and depth = 10
# [31]	valid_0's l2: 0.087396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and depth = 10
# [32]	valid_0's l2: 0.0869257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and depth = 10
# [33]	valid_0's l2: 0.0867282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and depth = 10
# [34]	valid_0's l2: 0.0865677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and depth = 10
# [35]	valid_0's l2: 0.0863843
# [LightGBM] [Debug] Re-bagging, using 3130 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and depth = 10
# [36]	valid_0's l2: 0.0857835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and depth = 10
# [37]	valid_0's l2: 0.085175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [38]	valid_0's l2: 0.0847347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 18 and depth = 10
# [39]	valid_0's l2: 0.0845503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and depth = 10
# [40]	valid_0's l2: 0.0844054
# [LightGBM] [Debug] Re-bagging, using 3110 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and depth = 10
# [41]	valid_0's l2: 0.0842451
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 35 and depth = 10
# [42]	valid_0's l2: 0.0838351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and depth = 10
# [43]	valid_0's l2: 0.0835236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and depth = 10
# [44]	valid_0's l2: 0.0834414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 10
# [45]	valid_0's l2: 0.0833413
# [LightGBM] [Debug] Re-bagging, using 3150 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and depth = 10
# [46]	valid_0's l2: 0.0831777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and depth = 10
# [47]	valid_0's l2: 0.0828473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [48]	valid_0's l2: 0.0825839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 10
# [49]	valid_0's l2: 0.0821842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [50]	valid_0's l2: 0.0820005
# [LightGBM] [Debug] Re-bagging, using 3184 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and depth = 10
# [51]	valid_0's l2: 0.0816021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 24 and depth = 10
# [52]	valid_0's l2: 0.081257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 50 and depth = 10
# [53]	valid_0's l2: 0.0803552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and depth = 10
# [54]	valid_0's l2: 0.0802247
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 10
# [55]	valid_0's l2: 0.0796495
# [LightGBM] [Debug] Re-bagging, using 3114 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and depth = 10
# [56]	valid_0's l2: 0.0794885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and depth = 10
# [57]	valid_0's l2: 0.0793504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 19 and depth = 10
# [58]	valid_0's l2: 0.0790687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and depth = 10
# [59]	valid_0's l2: 0.0787171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 29 and depth = 10
# [60]	valid_0's l2: 0.0785945
# [LightGBM] [Debug] Re-bagging, using 3163 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and depth = 10
# [61]	valid_0's l2: 0.0782904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and depth = 10
# [62]	valid_0's l2: 0.0782542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [63]	valid_0's l2: 0.0780737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 51 and depth = 10
# [64]	valid_0's l2: 0.077657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and depth = 10
# [65]	valid_0's l2: 0.0776016
# [LightGBM] [Debug] Re-bagging, using 3127 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 16 and depth = 10
# [66]	valid_0's l2: 0.0775093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and depth = 10
# [67]	valid_0's l2: 0.0773802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 41 and depth = 10
# [68]	valid_0's l2: 0.0771141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 10
# [69]	valid_0's l2: 0.0770456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 18 and depth = 10
# [70]	valid_0's l2: 0.0769303
# [LightGBM] [Debug] Re-bagging, using 3159 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and depth = 10
# [71]	valid_0's l2: 0.076405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 33 and depth = 10
# [72]	valid_0's l2: 0.0758537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and depth = 10
# [73]	valid_0's l2: 0.0755563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 55 and depth = 10
# [74]	valid_0's l2: 0.0750863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 32 and depth = 10
# [75]	valid_0's l2: 0.0748915
# [LightGBM] [Debug] Re-bagging, using 3120 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and depth = 10
# [76]	valid_0's l2: 0.0746662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and depth = 10
# [77]	valid_0's l2: 0.074471
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 23 and depth = 10
# [78]	valid_0's l2: 0.0742866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and depth = 10
# [79]	valid_0's l2: 0.0740113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 14 and depth = 10
# [80]	valid_0's l2: 0.0739017
# [LightGBM] [Debug] Re-bagging, using 3080 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 25 and depth = 10
# [81]	valid_0's l2: 0.0737587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# [82]	valid_0's l2: 0.0735874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 20 and depth = 10
# [83]	valid_0's l2: 0.0734111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and depth = 10
# [84]	valid_0's l2: 0.0733552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and depth = 10
# [85]	valid_0's l2: 0.0733868
# [LightGBM] [Debug] Re-bagging, using 3134 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 37 and depth = 10
# [86]	valid_0's l2: 0.0730298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and depth = 10
# [87]	valid_0's l2: 0.0730489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 38 and depth = 10
# [88]	valid_0's l2: 0.0730546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 28 and depth = 10
# [89]	valid_0's l2: 0.0728791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 30 and depth = 10
# [90]	valid_0's l2: 0.0729477
# [LightGBM] [Debug] Re-bagging, using 3166 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 36 and depth = 10
# [91]	valid_0's l2: 0.0728847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 40 and depth = 10
# [92]	valid_0's l2: 0.0727624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 22 and depth = 10
# [93]	valid_0's l2: 0.072708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 21 and depth = 10
# [94]	valid_0's l2: 0.0727065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 27 and depth = 10
# [95]	valid_0's l2: 0.0726667
# [LightGBM] [Debug] Re-bagging, using 3130 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 53 and depth = 10
# [96]	valid_0's l2: 0.072209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 48 and depth = 10
# [97]	valid_0's l2: 0.0718953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 34 and depth = 10
# [98]	valid_0's l2: 0.0719059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 26 and depth = 10
# [99]	valid_0's l2: 0.0719059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 18 and depth = 10
# [100]	valid_0's l2: 0.0718505
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's l2: 0
#  (0, 0.19321643779217926),
#  (0, 0.14971752754143042),
#  (0, 0.14111513224914382),
#  (0, 0.11417563274350925),
#  (0, 0.1375547782644233),
#  (0, 0.16276566069759413),
#  (0, 0.17850819948288066),
#  (0, 0.08623889258422511),
#  (0, 0.2559221973247831),
#  (0, 0.24105490863493056),
#  (0, 0.22534413248654686),
#  (0, 0.12287555719183742),
#  (1, 0.1215939687589521),
#  (1, 0.08079472127315689),
#  (1, 0.0647134109875111),
#  (0, 0.11405717755559822),
#  (0, 0.05451891099769189),
#  (0, -0.00013879380411194046),
#  (0, 0.07104913035500726),
#  (0, 0.10266789439796964),
#  (0, 0.14806125120809474),
#  (0, 0.08407441774940208),
#  (0, 0.15294852208397772),
#  (0, 0.1822744679503894),
#  (0, 0.18434710107291544),
#  (0, 0.19178246136395605),
#  (0, 0.210336788080399),
#  (0, 0.10880859578320685),
#  (0, 0.15665922542435387),
#  (0, 0.27711271659097214),
#  (0, 0.15735432585511508),
#  (0, 0.2742666275246641),
#  (0, 0.26026375496529475),
#  (0, 0.25445785472345495),
#  (0, 0.27990788532627725),
#  (0, 0.30855867538577375),
#  (0, 0.3110169201273289),
#  (0, 0.31434494405295815),
#  (0, 0.31652034265393997),
#  (0, 0.2212775581798557),
#  (0, 0.3073493429994227),
#  (0, 0.2471257191950589),
#  (0, 0.24862456673857242),
#  (0, 0.18751608971349454),
#  (0, 0.23125560469524523),
#  (0, 0.031606976292593354),
#  (0, 0.16320300804445612),
#  (0, 0.2450250842971438),
#  (0, 0.22463359241702413),
#  (0, 0.2974707002639182),
#  (0, 0.2270914260281045),
#  (0, 0.31983389017706754),
#  (0, 0.3111962861278563),
#  (0, 0.23463384672345095),
#  (0, 0.304140505890974),
#  (0, 0.21838581532145301),
#  (0, 0.265944225668342),
#  (0, 0.14984609594285586),
#  (0, 0.2450391155608272),
#  (0, 0.2784905542682214),
#  (0, 0.24222864026346322)]

# %%
s = 'aaasdfbbcc'

# %%
def solution(s):
    # Write your code here
    once = []

    for l in set(s):
        if s.count(l)<=1:
            tmp = [l, s.count(l)]
            once.append(tmp)
    
    if len(once)==0:
        out = -1
    else:
        
        idx = []
        for i in dict(once).keys():
            idx.append([i, s.find(i)])
            
        out = s.find(min(dict(idx), key=dict(idx).get))+1
    
    return out

# %%
solution(s)
# Out:
# 4

# %%
n = 24

# %%
x = list(str(n))

# %%
list(map(int, x))
# Out:
# [2, 4]

# %%
def solution(n):
    # Write your code here
    
    # factorial 계산 함수 작성
    def factorial(n):
        fact = 1
        for i in range(1, n+1):
            fact *= i
        return fact
    
        
    out = [list(map(int, x)) for x in list(str(n))]

    return out

# %%
n = 4

# %%
    
# 공격력 산출 함수 작성
def power(n):    

    # factorial 계산 함수 작성
    def factorial(n):
        fact = 1
        for i in range(1, n+1):
            fact *= i
        return fact


    out = [x for x in list(str(n))] # 각 자리수 list로 변환
    # factorial 실행 및 공격력 생성
    power = 0
    for i in out:
        power += factorial(int(i))
    return power

team = [n]
while True:

    n = power(n)

    if n in team:
        break
    team.append(n)

# %%
max(team)*len(team)
# Out:
# 2908808

# %%
arr = [4,1,2,3,6,9]

# %%
    # 처음으로 증가하기 시작한 배열 index추출
    stt = 0
    for idx, val in enumerate(list(arr)):
        if idx == len(arr)-1:
            pass
            
        else:
            
            if arr[idx] > arr[idx+1]:
                pass
            else:
                stt = idx
                break

# %%
arr2 = arr[stt:]

# %%
for idx, val in enumerate(list(arr2)):
    print(idx, val)
# Out:
# 0 1
# 1 2
# 2 3
# 3 6
# 4 9

# %%
end = len(arr)-1
for idx, val in enumerate(list(arr2)):
    print(idx, val)
    if idx == len(arr2)-1:
        pass
    else:
        if arr2[idx] >= arr2[idx+1]:
            end = idx
            pass
        else:
            break
# Out:
# 0 1

# %%
end
# Out:
# 0

# %%
end
# Out:
# 5

# %%
for idx, val in enumerate(reversed(list(arr))):
    if idx == len(arr)-1:
        end = idx
    else:
        if arr[idx] > arr[idx+1]:
            pass
        else:
            end = len(arr) - idx - 1
            break

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'solution' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY arr as parameter.
#

def solution(arr):
    # Write your code here
    
    updown =[]
    for idx, val in enumerate(list(arr)):
        if idx == 0:
            if arr[idx] <= arr[idx+1]:
                updown.append([idx, val, 'upper'])
            else:
                updown.append([idx, val, 'down'])
        elif idx == len(arr)-1:
            if arr[idx-1] >= arr[idx]:
                updown.append([idx, val, 'lower'])
            else:
                updown.append([idx, val, 'up'])
        else:
            if arr[idx-1]<=arr[idx]<=arr[idx+1]:
                updown.append([idx, val, 'up'])
            elif arr[idx-1]>=arr[idx]>=arr[idx+1]:
                updown.append([idx, val, 'down'])
            elif arr[idx-1]>arr[idx] and arr[idx]<=arr[idx+1]:
                updown.append([idx, val, 'lower'])
            elif arr[idx-1]<=arr[idx] and arr[idx]>arr[idx+1]:
                updown.append([idx, val, 'upper'])
                    
              
    
    return updown

    
    
if __name__ == '__main__':

# %%
def solution(arr):
    # Write your code here
    
    # 처음으로 증가하기 시작한 배열 index추출
    stt = 0
    for idx, val in enumerate(list(arr)):
        if idx == len(arr)-1:
            pass
            
        else:
            
            if arr[idx] > arr[idx+1]:
                pass
            else:
                stt = idx
                break
    
    # 역순으로 감소가 발생하기 시작하는 index추출
    end = 0
    arr2 = arr[stt:]
    for idx, val in enumerate(reversed(list(arr2))):
        if idx == len(arr2)-1:
            end = len(arr)
            
        else:
            if arr2[idx] > arr2[idx+1]:
                pass
            else:
                end = len(arr2) - idx - 1
                break
    
    return stt, end
# Out:
# 4

# %%
def avg_percentage(game_id, ft_number, team, result):
    """
    :param game_id: (list) The ID of the game. 
    :param ft_number: (list) The number of the free throw.
    :param team: (list) Which team took the free throw.
    :param result: (list) The result of the free throw, which is either missed or made.
    :returns: (float) The mean value of the percentages (0.0-100.0) of free throws that
               each team scored in each game.
    """
    
    df = pd.DataFrame({'game_id':game_id,
                       'ft_number':ft_number,
                       'team':team,
                       'result':result
                      })
    
    
    return df

#For example, with the parameters below, the function should return 58.33
df = avg_percentage(
    [1, 1, 1, 1, 2, 2],
    [1, 2, 3, 4, 1, 2],
    ['home','home','away','home','away','home'],
    ['made','missed','made','missed','missed','made']
)

# %%
df
# Out:
#    game_id  ft_number  team  result
# 0        1          1  home    made
# 1        1          2  home  missed
# 2        1          3  away    made
# 3        1          4  home  missed
# 4        2          1  away  missed
# 5        2          2  home    made

# %%
df['result'] = df['result'].apply(lambda x: 1 if x=='made' else 0)

# %%
df.groupby(['team','game_id']).agg({'ft_number':'count', 'result':'sum'})
# Out:
#               ft_number  result
# team game_id
# away 1                1       1
#      2                1       0
# home 1                3       1
#      2                1       1

# %%
dfg = df.groupby(['team','game_id']).count()

# %%
dfg
# Out:
#               ft_number  result
# team game_id
# away 1                1       1
#      2                1       1
# home 1                3       3
#      2                1       1

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

def train_and_predict(train_input_features, train_outputs, prediction_features):
    """
    :param train_input_features: (numpy.array) A two-dimensional NumPy array where each element
                        is an array that contains two numerical features
    :param train_outputs: (numpy.array) A one-dimensional NumPy array where each element
                        is the value associated with the same row of train_input_features
    :param prediction_features: (numpy.array) A two-dimensional NumPy array where each element
                        is an array that contains two numerical features
    :returns: (list) The function should return an iterable (like list or numpy.ndarray) of predictions,
                        one for each item in prediction_features
    """   
    pass

#Example case
np.random.seed(1)
data = np.random.normal(size=(200, 2))
result = 2 * data[:, 0] ** 3 + 4 * data[:, 1]
X_train, X_test, y_train, y_test = train_test_split(data, result,
                                                    test_size=0.3, random_state=0)

y_pred = train_and_predict(X_train, y_train, X_test)
if y_pred is not None:
    print(metrics.mean_squared_error(y_test, y_pred))

# %%
poly = PolynomialFeatures(degree=2)
X_ = poly.fit_transform(X)
predict_ = poly.fit_transform(predict)

clf = linear_model.LinearRegression()
clf.fit(X_, vector)
print clf.predict(predict_)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
poly = PolynomialFeatures(degree=3)

X_train_poly = poly.fit_transform(X_train)

X_test_poly = poly.transform(X_test)

model = LinearRegression()
model.fit(X_train_poly, y_train)

y_pred = model.predict(X_test_poly)

# %%
import pandas as pd
import math

def num_names(names, required_pct):
    """
    :param names: (list) A list of first names.
    :param required_pct: (int) The required percentage of the sample data to be preprinted.
    :returns: (int) The minimum number of unique first names (or templates) that need to be prepared.
    """
    return None
        
names = ["James", "Sophia", "James", "Sophia", "James", "Sophia", "Emma", "Jack"]
print(num_names(names, 75))
# Out:
# None

# %%
df = pd.DataFrame(names)[0].value_counts().reset_index().rename(columns={'index':'name', 0:'count'})

# %%
df['cum_pct'] = df['count'].cumsum()/df['count'].sum()*100

# %%
required_pct = 75

# %%
row_num = df.query("cum_pct < {}".format(required_pct)).shape[0]+1

# %%
df.iloc[:row_num].shape[0]
# Out:
# 2

# %%
df.sort_values('count', ascending=False)
# Out:
#                   name  count
# 0                James      3
# 1          JamesSophia      6
# 2      JamesSophiaEmma      7
# 3  JamesSophiaEmmaJack      8

# %%
np.unique(names, return_counts=True)
# Out:
#       0     1      2       3
# 0  Emma  Jack  James  Sophia
# 1     1     1      3       3

# %%
counts
# Out:
# array([1, 1, 3, 3], dtype=int64)
